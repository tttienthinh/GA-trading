# %% [markdown]
# # Testing William fractal strategy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output

import ta, pickle, json, time

# %% [markdown]
# # Import

# %%
df = pd.read_csv("../data/train.csv")
plt.plot(df.open[:100])

# %%
def wilFractal(df):
        bear = (
                df['high'].shift(2).lt(df['high']) &
                df['high'].shift(1).lt(df['high']) &
                df['high'].shift(-1).lt(df['high']) &
                df['high'].shift(-2).lt(df['high'])
        )
    
        bull = (
                df['low'].shift(2).gt(df['low']) &
                df['low'].shift(1).gt(df['low']) &
                df['low'].shift(-1).gt(df['low']) &
                df['low'].shift(-2).gt(df['high'])
        )
    
        return bear, bull
    
def ema(df, windows=[20]):
    emas = []
    for x in windows:
        emas.append(
            ta.trend.ema_indicator(close=df.close, window=x, fillna=True)
        )
    return emas

# %%
df['bear'], df['bull'] = wilFractal(df)
df['ema20'], df['ema50'], df['ema100'] = ema(df, [20, 50, 100])
df
# Out:
#                 timestamp      open      high       low     close      volume  \
# 0     2021-05-15 22:02:00  48439.11  48523.38  48435.98  48506.05   19.263924
# 1     2021-05-15 22:03:00  48506.04  48506.04  48448.00  48454.97   21.732334
# 2     2021-05-15 22:04:00  48454.97  48456.95  48378.85  48380.19   34.397880
# 3     2021-05-15 22:05:00  48378.86  48378.86  48310.89  48320.64   28.305630
# 4     2021-05-15 22:06:00  48320.64  48484.49  48320.63  48437.13   42.514373
# ...                   ...       ...       ...       ...       ...         ...
# 1435  2021-05-16 21:57:00  45199.99  45207.20  45000.78  45030.13  141.534753
# 1436  2021-05-16 21:58:00  45030.13  45146.76  45016.15  45092.04  124.272071
# 1437  2021-05-16 21:59:00  45092.04  45234.66  45090.00  45195.96   81.029058
# 1438  2021-05-16 22:00:00  45195.29  45321.26  45163.65  45273.19  139.839558
# 1439  2021-05-16 22:01:00  45273.19  45396.94  45245.00  45379.60   68.105941
#
#        bear   bull         ema20         ema50        ema100
# 0     False  False  48506.050000  48506.050000  48506.050000
# 1     False  False  48501.185238  48504.046863  48505.038515
# 2     False  False  48489.661882  48499.189731  48502.566267
# 3     False   True  48473.564560  48492.187781  48498.963767
# 4     False  False  48470.094602  48490.028652  48497.739336
# ...     ...    ...           ...           ...           ...
# 1435  False  False  45159.135055  44955.436382  44958.730195
# 1436  False  False  45152.745050  44960.793386  44961.369993
# 1437  False  False  45156.860760  44970.015607  44966.015340
# 1438  False  False  45167.939735  44981.904799  44972.098006
# 1439  False  False  45188.097855  44997.500689  44980.167353
#
# [1440 rows x 11 columns]

# %%
plt.plot(df.close[:100], label='Price')
plt.plot(df.ema20[:100], label='EMA20')
plt.plot(df.ema50[:100], label='EMA50')
plt.plot(df.ema100[:100], label='EMA100')
plt.plot(np.array(range(100))[df.bear[:100]], df.close[:100][df.bear[:100]] + 100, 
         "vr", label='Bear')
plt.plot(np.array(range(100))[df.bull[:100]], df.close[:100][df.bull[:100]] - 100, 
         "^g", label='Bull')
plt.legend()

# %% [markdown]
# # Trading

# %%
def trade(df, low, high, start):
    ls = df.values.tolist()
    n = len(ls)
    for i in range(n):
        if ls[i][0] > high: # test high
            return high, i
        if ls[i][1] < low: # test low
            return low, i
    return start, n

# %%
trades = pd.DataFrame(columns=["i", "timestamp", "Action", "Start", "End", "Benef", "Duration"])
for i in range(len(df)):
    timestamp, o, h, l, c, v, bear, bull, ema20, ema50, ema100 = df.iloc[i]
    if ema20 < ema50 < ema100: # SELL only
        if bear:
            trigger = False
            if ema50 < h < ema100:
                trigger = True
                SL = ema100
            if ema20 < h < ema50:
                trigger = True
                SL = ema50
            if trigger:
                start = df.close[i+2]
                TP = start - 1.5 * (SL - start)
                end, n = trade(df[['high', 'low']][i+2:i+122], TP, SL, start)
                trades = trades.append({
                    "i": i+2,
                    "timestamp" : timestamp,
                    "Action" : "SELL",
                    "Start" : start,
                    "End" : end,
                    "Benef" : start-end,
                    "Duration" : n
                }, ignore_index=True)
    
    if ema20 > ema50 > ema100: # BUY only
        if bull:
            trigger = False
            if ema50 > l > ema100:
                trigger = True
                SL = ema100
            if ema20 > h > ema50:
                trigger = True
                SL = ema50
            if trigger:
                start = df.close[i+2]
                TP = start + 1.5 * (start - SL)
                end, n = trade(df[['high', 'low']][i+2:i+122], SL, TP, start)
                trades = trades.append({
                    "i": i+2,
                    "timestamp" : timestamp,
                    "Action" : "SELL",
                    "Start" : start,
                    "End" : end,
                    "Benef" : end-start,
                    "Duration" : n
                }, ignore_index=True)

# %%
trades
# Out:
#        i            timestamp Action     Start           End       Benef  \
# 0      7  2021-05-15 22:07:00   SELL  48420.73  48496.390834  -75.660834
# 1     52  2021-05-15 22:52:00   SELL  48071.70  47647.036006  424.663994
# 2     56  2021-05-15 22:56:00   SELL  47936.99  47487.800364  449.189636
# 3     76  2021-05-15 23:16:00   SELL  47646.96  47175.304073  471.655927
# 4     99  2021-05-15 23:39:00   SELL  46703.12  47584.741507 -881.621507
# ..   ...                  ...    ...       ...           ...         ...
# 56  1375  2021-05-16 20:55:00   SELL  44461.76  44815.193142 -353.433142
# 57  1386  2021-05-16 21:06:00   SELL  44731.06  44242.594845  488.465155
# 58  1389  2021-05-16 21:09:00   SELL  44704.81  44214.060245  490.749755
# 59  1393  2021-05-16 21:13:00   SELL  44496.28  45002.889124 -506.609124
# 60  1407  2021-05-16 21:27:00   SELL  44569.56  44843.490293 -273.930293
#
#    Duration
# 0         1
# 1        11
# 2        23
# 3        16
# 4        34
# ..      ...
# 56        8
# 57       10
# 58        8
# 59       21
# 60        6
#
# [61 rows x 7 columns]

# %%
trades.mean()
# Out:
# Start       47353.106557
# End         47333.529196
# Benef          25.433765
# Duration       14.688525
# dtype: float64

# %%
plt.figure(figsize=(24, 12), dpi=80)

plt.plot(df.close, label='Price')
plt.plot(df.ema20, label='EMA20')
plt.plot(df.ema50, label='EMA50')
plt.plot(df.ema100, label='EMA100')
plt.plot(trades.i, df.close.iloc[trades.i] + 100, 
         "vr", label='SELL')
plt.plot(trades.i + trades.Duration, df.close.iloc[trades.i + trades.Duration] - 100, 
         "^g", label='CLOSE')
plt.legend()

# %%
trades.i
# Out:
# 0        7
# 1       52
# 2       56
# 3       76
# 4       99
#       ...
# 56    1375
# 57    1386
# 58    1389
# 59    1393
# 60    1407
# Name: i, Length: 61, dtype: object

# %%
df.close.iloc[trades.i]
# Out:
# 7       48420.73
# 52      48071.70
# 56      47936.99
# 76      47646.96
# 99      46703.12
#           ...
# 1375    44461.76
# 1386    44731.06
# 1389    44704.81
# 1393    44496.28
# 1407    44569.56
# Name: close, Length: 61, dtype: float64

# %%
len(df)
# Out:
# 1440
